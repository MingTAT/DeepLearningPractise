# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cars.csv')

# %%
df
# Out:
#     Unnamed: 0  speed  dist
# 0            1      4     2
# 1            2      4    10
# 2            3      7     4
# 3            4      7    22
# 4            5      8    16
# 5            6      9    10
# 6            7     10    18
# 7            8     10    26
# 8            9     10    34
# 9           10     11    17
# 10          11     11    28
# 11          12     12    14
# 12          13     12    20
# 13          14     12    24
# 14          15     12    28
# 15          16     13    26
# 16          17     13    34
# 17          18     13    34
# 18          19     13    46
# 19          20     14    26
# 20          21     14    36
# 21          22     14    60
# 22          23     14    80
# 23          24     15    20
# 24          25     15    26
# 25          26     15    54
# 26          27     16    32
# 27          28     16    40
# 28          29     17    32
# 29          30     17    40
# 30          31     17    50
# 31          32     18    42
# ...

# %%
x = df['speed']

# %%
y = df['dist']

# %%
# %matplotlib inline

# %%
plt.show()

# %%
plt.plot(x, y, '*')

# %%
df.plot(x = 'speed' , y = 'dist', kind = 'Sca ')
